# %%
import matplotlib.pyplot as plt

# %%
graph.index[1:16]
# Out:
# Index(['ADA/BUSD', 'ADA/EUR', 'ADA/TRY', 'ADA/USD', 'ADA/USDT', 'ALGO/BTC',
#        'ALGO/BUSD', 'ALGO/EUR', 'ALGO/GBP', 'ALGO/USD', 'ALGO/USDT',
#        'AVAX/BNB', 'AVAX/BTC', 'AVAX/BUSD', 'AVAX/EUR'],
#       dtype='object', name='symbol')

# %%
plt.style.use('ggplot')

graph = new_df.groupby(['symbol', 'ex'])['volume'].sum().unstack()
graph[:6].plot(kind='bar',stacked=True)

plt.figsize=(25, 22)
plt.xlabel('Quotes')
plt.ylabel('Volume(sum)')
plt.title('ADA/')
plt.xticks(rotation=20, fontsize=9)
plt.legend(loc='best', prop={'size': 6})
plt.savefig('volume_on_the_ADA_2021_10_07_cmc', dpi=300)

plt.show()
